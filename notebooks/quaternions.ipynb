# %%
from pytransform3d.rotations import *
from pytransform3d.rotations import quaternion_integrate
import numpy as np

# %%
R = np.eye(3)
# plot_basis(R=R)
a = axis_angle_from_matrix(R=R)
print(a)
plot_axis_angle(a=[1,1,1,0])
matrix_from_axis_angle([1,1,1,0])
quaternion_from_matrix(R)
# quaternion_from_axis_angle(a)
from pytransform3d.plot_utils import plot_vector
plot_vector(direction=[1,1,1])
quaternion_integrate
# Out:
# [1. 0. 0. 0.]
